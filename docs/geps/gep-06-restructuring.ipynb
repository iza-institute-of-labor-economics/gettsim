# %% [markdown]
# # Restructuring of variables and parameters

# %%
from flatten_dict import flatten
from flatten_dict.reducers import make_reducer
from pybaum.registry import get_registry
from pybaum.tree_util import tree_map

# %%
current_structure = {
    "social_insurance_contributions/ges_pflegev.py": [
        "_ges_pflegev_beitr_midijob_arbeitg_m_residuum",
        "_ges_pflegev_beitr_midijob_arbeitn_m_anteil_beitragspfl_einnahme",
        "_ges_pflegev_beitr_midijob_sum_arbeitn_arbeitg_m",
        "ges_pflegev_beitr_arbeitg_m",
        "ges_pflegev_beitr_m",
        "ges_pflegev_beitr_rente_m",
        "ges_pflegev_beitr_selbst_m",
        "ges_pflegev_zusatz_kinderlos",
    ],
    "social_insurance_contributions/ges_krankenv.py": [
        "_ges_krankenv_beitr_midijob_arbeitg_m_residuum",
        "_ges_krankenv_beitr_midijob_arbeitn_m_anteil_beitragspfl_einnahme",
        "_ges_krankenv_beitr_midijob_sum_arbeitn_arbeitg_m",
        "_ges_krankenv_beitr_reg_beschäftigt_m",
        "_ges_krankenv_beitr_satz_arbeitg_zusatzbeitrag_paritätisch",
        "_ges_krankenv_bemessungsgrundlage_eink_selbst",
        "_ges_krankenv_bemessungsgrundlage_rente_m",
        "_ges_krankenv_bruttolohn_m",
        "ges_krankenv_beitr_arbeitg_m",
        "ges_krankenv_beitr_m",
        "ges_krankenv_beitr_rente_m",
        "ges_krankenv_beitr_satz_zusatzbeitrag_paritätisch",
        "ges_krankenv_beitr_selbst_m",
        "ges_krankenv_mean_zusatzbeitrag",
    ],
    "social_insurance_contributions/beitr_bemess_grenzen.py": [
        "_ges_krankenv_beitr_bemess_grenze_m",
        "_ges_krankenv_bezugsgröße_selbst_m",
        "_ges_rentenv_beitr_bemess_grenze_m",
    ],
    "social_insurance_contributions/eink_grenzen.py": [
        "_midijob_beitragspfl_einnahme_arbeitn_m",
        "geringfügig_beschäftigt",
        "in_gleitzone",
        "midijob_bemessungsentgelt_m_ab_10_2022",
        "midijob_faktor_f_ohne_minijob_st",
        "minijob_grenze",
        "regulär_beschäftigt",
    ],
    "social_insurance_contributions/ges_rentenv.py": [
        "_ges_rentenv_beitr_bruttolohn_m",
        "_ges_rentenv_beitr_midijob_arbeitg_m_residuum",
        "_ges_rentenv_beitr_midijob_arbeitn_m_anteil_beitragspfl_einnahme",
        "_ges_rentenv_beitr_midijob_sum_arbeitn_arbeitg_m",
        "ges_rentenv_beitr_arbeitg_m",
        "ges_rentenv_beitr_m",
    ],
    "social_insurance_contributions/arbeitsl_v.py": [
        "_arbeitsl_v_beitr_midijob_arbeitg_m_residuum",
        "_arbeitsl_v_beitr_midijob_arbeitn_m_anteil_beitragspfl_einnahme",
        "_arbeitsl_v_beitr_midijob_sum_arbeitn_arbeitg_m",
        "_sozialv_beitr_arbeitn_arbeitg_m",
        "arbeitsl_v_beitr_arbeitg_m",
        "arbeitsl_v_beitr_m",
        "sozialv_beitr_arbeitg_m",
        "sozialv_beitr_m",
    ],
    "transfers/arbeitsl_geld.py": [
        "arbeitsl_geld_berechtigt",
        "arbeitsl_geld_eink_vorj_proxy_m",
        "arbeitsl_geld_m",
        "arbeitsl_geld_restl_anspruchsd",
    ],
    "transfers/elterngeld.py": [
        "_elterngeld_anz_mehrlinge_anspruch",
        "_elterngeld_proxy_eink_vorj_elterngeld_m",
        "elterngeld_anr_m",
        "elterngeld_anteil_eink_erlass",
        "elterngeld_eink_erlass_m",
        "elterngeld_eink_relev_m",
        "elterngeld_geschw_bonus_anspruch",
        "elterngeld_geschw_bonus_m",
        "elterngeld_kind",
        "elterngeld_m",
        "elterngeld_mehrlinge_bonus_m",
        "elterngeld_nettolohn_m",
        "elterngeld_vorschulkind",
        "elternzeit_anspruch",
    ],
    "transfers/grundrente.py": [
        "_grundr_zuschlag_eink_vor_freibetrag_m",
        "grundr_berechtigt",
        "grundr_bew_zeiten_avg_entgeltp",
        "grundr_zuschlag_bonus_entgeltp",
        "grundr_zuschlag_eink_m",
        "grundr_zuschlag_höchstwert_m",
        "grundr_zuschlag_m",
        "grundr_zuschlag_vor_eink_anr_m",
        "rente_vorj_vor_grundr_proxy_m",
    ],
    "transfers/grunds_im_alter.py": [
        "_grunds_im_alter_kapitaleink_brutto_m",
        "_grunds_im_alter_mehrbedarf_schwerbeh_g_m",
        "grunds_im_alter_eink_m",
        "grunds_im_alter_erwerbseink_m",
        "grunds_im_alter_ges_rente_m_ab_2021",
        "grunds_im_alter_m_hh",
        "grunds_im_alter_priv_rente_m",
        "grunds_im_alter_vermög_freib_hh",
    ],
    "transfers/rente.py": [
        "_ges_rente_altersgrenze_abschlagsfrei_mit_besond_langj",
        "_ges_rente_besond_langj_altersgrenze",
        "_ges_rente_langj_altersgrenze",
        "entgeltp_update",
        "entgeltp_update_lohn",
        "ges_rente_anrechnungszeit",
        "ges_rente_anrechnungszeit_45",
        "ges_rente_frauen_altersgrenze",
        "ges_rente_m_nach_grundr",
        "ges_rente_regelaltersgrenze",
        "ges_rente_vor_grundr_m",
        "ges_rente_vorauss_besond_langj",
        "ges_rente_vorauss_frauen",
        "ges_rente_vorauss_langj",
        "ges_rente_vorauss_regelrente",
        "ges_rente_vorauss_vorzeitig",
        "ges_rente_wartezeit_15",
        "ges_rente_wartezeit_35",
        "ges_rente_wartezeit_45",
        "ges_rente_wartezeit_5",
        "ges_rente_zugangsfaktor",
        "referenz_alter_abschlag",
        "rentenwert",
        "rentenwert_vorjahr",
        "sum_ges_rente_priv_rente_m",
    ],
    "transfers/wohngeld.py": [
        "_anteil_personen_in_haushalt_tu",
        "wohngeld_abzüge_st_sozialv_m",
        "wohngeld_arbeitendes_kind",
        "wohngeld_eink_freib_m_ab_2016",
        "wohngeld_eink_m_hh",
        "wohngeld_eink_vor_freib_m_mit_elterngeld",
        "wohngeld_m_hh",
        "wohngeld_miete_m_hh_ab_2009",
        "wohngeld_min_miete_m_hh",
        "wohngeld_vor_vermög_check_m_hh",
    ],
    "transfers/unterhaltsvors.py": [
        "unterhaltsvors_m",
        "unterhaltsvorschuss_eink_m_tu",
    ],
    "transfers/kinderbonus.py": ["kinderbonus_m"],
    "transfers/unterhalt.py": ["kind_unterh_zahlbetr_m"],
    "transfers/kindergeld.py": ["kindergeld_anspruch_nach_stunden", "kindergeld_m"],
    "transfers/benefit_checks/benefit_checks.py": [
        "kinderzuschl_vorrang_hh",
        "wohngeld_kinderzuschl_vorrang_hh",
        "wohngeld_vorrang_hh",
    ],
    "transfers/benefit_checks/vermoegens_checks.py": [
        "_arbeitsl_geld_2_grundfreib_vermög",
        "_arbeitsl_geld_2_max_grundfreib_vermög",
        "_kinderzuschl_nach_vermög_check_m_tu",
        "arbeitsl_geld_2_vermög_freib_hh_ab_2023",
        "wohngeld_nach_vermög_check_m_hh",
    ],
    "transfers/kinderzuschl/kinderzuschl_eink.py": [
        "kinderzuschl_bruttoeink_eltern_m",
        "kinderzuschl_eink_anrechn_m_tu",
        "kinderzuschl_eink_eltern_m",
        "kinderzuschl_eink_min_m_tu",
        "kinderzuschl_eink_regel_m_tu",
        "kinderzuschl_eink_relev_m_tu",
        "kinderzuschl_kindereink_abzug_m",
    ],
    "transfers/kinderzuschl/kinderzuschl.py": [
        "_kinderzuschl_vor_vermög_check_m_tu",
        "kinderzuschl_m_hh",
    ],
    "transfers/kinderzuschl/kost_unterk.py": [
        "_kinderzuschl_wohnbedarf_eltern_anteil_tu",
        "bruttokaltmiete_m_tu",
        "heizkosten_m_tu",
        "kinderzuschl_kost_unterk_m_tu",
    ],
    "transfers/arbeitsl_geld_2/arbeitsl_geld_2.py": [
        "_arbeitsl_geld_2_alleinerz_mehrbedarf_m_hh",
        "arbeitsl_geld_2_kindersatz_m_hh_ab_2011",
        "arbeitsl_geld_2_m_hh",
        "arbeitsl_geld_2_regelbedarf_m_hh",
        "arbeitsl_geld_2_regelsatz_m_hh_ab_2011",
        "arbeitsl_geld_2_vor_vorrang_m_hh",
    ],
    "transfers/arbeitsl_geld_2/kost_unterk.py": [
        "_arbeitsl_geld_2_berechtigte_wohnfläche_hh",
        "_arbeitsl_geld_2_warmmiete_pro_qm_m_hh",
        "arbeitsl_geld_2_kost_unterk_m_hh_ab_2023",
    ],
    "transfers/arbeitsl_geld_2/arbeitsl_geld_2_eink.py": [
        "arbeitsl_geld_2_bruttoeink_m",
        "arbeitsl_geld_2_eink_anr_frei_m",
        "arbeitsl_geld_2_eink_m",
    ],
    "taxes/lohn_st.py": [
        "_lohnst_m",
        "_lohnsteuer_klasse5_6_basis",
        "kinderfreib_für_soli_st_lohnst",
        "lohnst_eink",
        "lohnst_m",
        "lohnst_mit_kinderfreib_m",
        "vorsorgepauschale_ab_2010",
    ],
    "taxes/eink_st.py": [
        "_eink_st_tarif",
        "eink_st_mit_kinderfreib_tu",
        "eink_st_ohne_kinderfreib_tu",
        "eink_st_rel_kindergeld_tu",
        "eink_st_tu_kindergeld_oder_kinderfreib",
        "kinderfreib_günstiger_tu",
    ],
    "taxes/abgelt_st.py": ["abgelt_st_tu", "zu_verst_kapitaleink_tu"],
    "taxes/soli_st.py": ["_soli_st_tarif", "soli_st_lohnst_m", "soli_st_tu"],
    "taxes/zu_verst_eink/freibetraege.py": [
        "_eink_st_behinderungsgrad_pauschbetrag",
        "eink_st_abz_betreuungskost",
        "eink_st_alleinerz_freib_tu_nach_kinderzahl",
        "eink_st_altersfreib_ab_2005",
        "eink_st_kinderfreib_tu",
        "eink_st_sonderausgaben_tu_mit_betreuung",
        "sonderausgaben_betreuung_tu",
    ],
    "taxes/zu_verst_eink/eink.py": [
        "_zu_verst_eink_abhängig_beschäftigt",
        "eink_abhängig_beschäftigt",
        "eink_rente_zu_verst",
        "eink_rente_zu_verst_m",
        "eink_selbst",
        "eink_vermietung",
        "kapitaleink",
        "kapitaleink_brutto",
        "rente_ertragsanteil",
        "sum_eink_ohne_kapital_eink",
    ],
    "taxes/zu_verst_eink/zu_verst_eink.py": [
        "_zu_verst_eink_ohne_kinderfreib_tu",
        "freibeträge_ind",
        "freibeträge_tu",
        "zu_verst_eink_mit_kinderfreib_tu",
        "zu_verst_eink_tu",
    ],
    "taxes/zu_verst_eink/vorsorgeaufw.py": [
        "_vorsorgeaufw_tu_ab_2020",
        "vorsorgeaufw_alter_tu",
        "vorsorgeaufw_tu_ab_2020",
    ],
    "demographic_vars.py": [
        "alter_monate",
        "eltern",
        "erwachsen",
        "erwachsene_alle_rentner_hh",
        "geburtsdatum",
        "gemeinsam_veranlagt_tu",
        "jüngstes_kind_oder_mehrling",
        "kind_ab_14_bis_17",
        "kind_ab_14_bis_24",
        "kind_ab_18_bis_24",
        "kind_ab_7_bis_13",
        "kind_bis_10",
        "kind_bis_15",
        "kind_bis_17",
        "kind_bis_6",
    ],
}

# %%
dicts = tree_map(
    func=lambda x: {y: "" for y in x},
    tree=current_structure,
    registry=get_registry(types=["dict"], include_defaults=False),
)

# %%
print(*list(flatten(dicts, reducer=make_reducer(delimiter="__"))), sep="\n")
